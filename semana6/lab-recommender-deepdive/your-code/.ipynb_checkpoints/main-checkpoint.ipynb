# %% [markdown]
# # Recommender Systems Deep-Dive Lab
#
# There are many different approaches that we can take when creating recommender systems. In the Intro to Recommender Systems lesson and lab, we put together a user similarity based recommender that first calculated the similarities between users and then leveraged a rank-based item recommender within each group of similar customers. In other words, for a given user, our recommender found the top 5 customers who were the most similar to them, aggregated and ranked the purchases of those 5 customers, and then recommended the top 5 most popular products among that group of similar users to the customer.
#
# In this lab, we are going to start out with the same data set, but we are going to dive deeper into the analysis of customers and products and look at an alternative way to generate recommendations.
#
# We will begin by importing everything we will need for this lab (libraries, data set, etc.).

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import pdist, squareform
from heapq import nlargest

data = pd.read_csv('../data/customer_product_sales.csv')

# %% [markdown]
# ## Data Preparation
#
# We will then put together the foundational transformations of the data that we will need to eventually produce recommendations. The steps in this section should be familiar to you, as you would have had to tranform the data in this manner to create the user similarity based recommender in the Intro to Recommender Systems lab.
#
# First, we will create a data frame that contains the total quantity of each product purchased by each customer.

# %%
#Create dataframe that shows the amount purchased per customer of each product
prods_per_consumer = pd.DataFrame(data.groupby(['CustomerID', 'ProductName'])['Quantity'].sum()).reset_index()
prods_per_consumer.head()
# Out:
#    CustomerID                    ProductName  Quantity
# 0          33               Apricots - Dried         1
# 1          33              Assorted Desserts         1
# 2          33        Bandage - Flexible Neon         1
# 3          33  Bar Mix - Pina Colada, 355 Ml         1
# 4          33         Beans - Kidney, Canned         1

# %% [markdown]
# Then, we want to create a matrix that has customers on one axis, products on the other, and the quantity purchased as the values. There will be many instances where a customer has not purchased a product, which by default will be expressed with a null value. We will want to replace those nulls with zeros by appending `.fillna(0)` to our pivot table.

# %%
#Create a matrix with ProductName, CustomerID and the quantity purchased of each product.
prods_matrix = pd.pivot_table(prods_per_consumer, 
                              index='ProductName', 
                              columns='CustomerID', 
                              values='Quantity', 
                              fill_value=0, 
                              aggfunc=np.sum)

prods_matrix.head()
# Out:
# CustomerID                         33     200    264    356    412    464    \
# ProductName
# Anchovy Paste - 56 G Tube              0      0      0      0      0      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0      0      0
# Appetizer - Mushroom Tart              0      0      0      0      0      0
# Appetizer - Sausage Rolls              0      0      0      0      0      0
# Apricots - Dried                       1      0      0      0      1      0
#
# CustomerID                         477    639    649    669    ...  97697  \
# ProductName                                                    ...
# Anchovy Paste - 56 G Tube              0      1      0      0  ...      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0      0  ...     25
# Appetizer - Mushroom Tart              0      1      0      0  ...     25
# Appetizer - Sausage Rolls              0      0      0      0  ...      0
# Apricots - Dried                       0      0      0      0  ...      0
#
# CustomerID                         97753  97769  97793  97900  97928  98069  \
# ProductName
# Anchovy Paste - 56 G Tube             25      0      0      0      0      0
# Appetizer - Mini Egg Roll, Shrimp     25      0      0      0      0      0
# Appetizer - Mushroom Tart              0      0      0      0      0      0
# Appetizer - Sausage Rolls              0      0      0     25     25     25
# Apricots - Dried                      25      0      0      0      0      0
#
# CustomerID                         98159  98185  98200
# ProductName
# Anchovy Paste - 56 G Tube              0      0      0
# Appetizer - Mini Egg Roll, Shrimp      0      0      0
# Appetizer - Mushroom Tart              0     25      0
# Appetizer - Sausage Rolls              0     25      0
# Apricots - Dried                       0      0      0
#
# [5 rows x 1000 columns]

# %% [markdown]
# In the pivot table we created, the rows represent the products and the columns represent the customers. Depending on what need to do with the matrix, we may instead need to transpose it so that the rows represent customers and the columns to represent products. We can do this easily by appending `.T` to our product customer matrix.

# %%
#Transpose the matrix so products are on columns
prods_matrix = prods_matrix.T
prods_matrix.head()
# Out:
# ProductName  Anchovy Paste - 56 G Tube  Appetizer - Mini Egg Roll, Shrimp  \
# CustomerID
# 33                                   0                                  0
# 200                                  0                                  0
# 264                                  0                                  0
# 356                                  0                                  0
# 412                                  0                                  0
#
# ProductName  Appetizer - Mushroom Tart  Appetizer - Sausage Rolls  \
# CustomerID
# 33                                   0                          0
# 200                                  0                          0
# 264                                  0                          0
# 356                                  0                          0
# 412                                  0                          0
#
# ProductName  Apricots - Dried  Apricots - Halves  Apricots Fresh  \
# CustomerID
# 33                          1                  0               0
# 200                         0                  0               0
# 264                         0                  1               1
# 356                         0                  0               0
# 412                         1                  0               0
#
# ProductName  Arizona - Green Tea  Artichokes - Jerusalem  Assorted Desserts  \
# CustomerID
# 33                             0                       0                  1
# 200                            0                       0                  0
# 264                            0                       0                  0
# 356                            0                       0                  0
# 412                            0                       0                  0
#
# ProductName  ...  Wine - White, Colubia Cresh  Wine - White, Mosel Gold  \
# CustomerID   ...
# 33           ...                            0                         0
# 200          ...                            1                         0
# 264          ...                            0                         0
# 356          ...                            0                         0
# 412          ...                            0                         1
#
# ProductName  Wine - White, Schroder And Schyl  Wine - Wyndham Estate Bin 777  \
# CustomerID
# 33                                          0                              0
# 200                                         0                              0
# 264                                         0                              1
# 356                                         0                              0
# 412                                         1                              1
#
# ProductName  Wonton Wrappers  Yeast Dry - Fermipan  Yoghurt Tubes  \
# CustomerID
# 33                         0                     0              0
# 200                        0                     0              0
# 264                        0                     0              0
# 356                        0                     0              0
# 412                        0                     0              0
#
# ProductName  Yogurt - Blueberry, 175 Gr  Yogurt - French Vanilla  \
# CustomerID
# 33                                    0                        1
# 200                                   1                        0
# 264                                   0                        0
# 356                                   0                        1
# 412                                   0                        0
#
# ProductName  Zucchini - Yellow
# CustomerID
# 33                           0
# 200                          0
# 264                          0
# 356                          0
# 412                          0
#
# [5 rows x 452 columns]

# %% [markdown]
# Another thing we may want to do is normalize the values across rows or columns of the matrix so that all the values are between 0 and 1. Doing this for customers would help us identify customers that may have purcahsed a similar mix of products even though some of those customers may have purchased large quantities while other may have purchased smaller quantities. Doing this for products would help us better identify products that have been purchased by similar groups of customers regardless of the quantities purchased.
#
# We can normalize across rows for each matrix as follows.

# %%
#standardize the matrix
prods_matrix= (prods_matrix - np.min(prods_matrix))/(np.max(prods_matrix) - np.min(prods_matrix))
prods_matrix.head()
# Out:
# ProductName  Anchovy Paste - 56 G Tube  Appetizer - Mini Egg Roll, Shrimp  \
# CustomerID
# 33                                 0.0                                0.0
# 200                                0.0                                0.0
# 264                                0.0                                0.0
# 356                                0.0                                0.0
# 412                                0.0                                0.0
#
# ProductName  Appetizer - Mushroom Tart  Appetizer - Sausage Rolls  \
# CustomerID
# 33                                 0.0                        0.0
# 200                                0.0                        0.0
# 264                                0.0                        0.0
# 356                                0.0                        0.0
# 412                                0.0                        0.0
#
# ProductName  Apricots - Dried  Apricots - Halves  Apricots Fresh  \
# CustomerID
# 33                   0.022727               0.00            0.00
# 200                  0.000000               0.00            0.00
# 264                  0.000000               0.02            0.02
# 356                  0.000000               0.00            0.00
# 412                  0.022727               0.00            0.00
#
# ProductName  Arizona - Green Tea  Artichokes - Jerusalem  Assorted Desserts  \
# CustomerID
# 33                           0.0                     0.0               0.02
# 200                          0.0                     0.0               0.00
# 264                          0.0                     0.0               0.00
# 356                          0.0                     0.0               0.00
# 412                          0.0                     0.0               0.00
#
# ProductName  ...  Wine - White, Colubia Cresh  Wine - White, Mosel Gold  \
# CustomerID   ...
# 33           ...                     0.000000                      0.00
# 200          ...                     0.015152                      0.00
# 264          ...                     0.000000                      0.00
# 356          ...                     0.000000                      0.00
# 412          ...                     0.000000                      0.02
#
# ProductName  Wine - White, Schroder And Schyl  Wine - Wyndham Estate Bin 777  \
# CustomerID
# 33                                       0.00                           0.00
# 200                                      0.00                           0.00
# 264                                      0.00                           0.04
# 356                                      0.00                           0.00
# 412                                      0.02                           0.04
#
# ProductName  Wonton Wrappers  Yeast Dry - Fermipan  Yoghurt Tubes  \
# CustomerID
# 33                       0.0                   0.0            0.0
# 200                      0.0                   0.0            0.0
# 264                      0.0                   0.0            0.0
# 356                      0.0                   0.0            0.0
# 412                      0.0                   0.0            0.0
#
# ProductName  Yogurt - Blueberry, 175 Gr  Yogurt - French Vanilla  \
# CustomerID
# 33                             0.000000                 0.021739
# 200                            0.020833                 0.000000
# 264                            0.000000                 0.000000
# 356                            0.000000                 0.021739
# 412                            0.000000                 0.000000
#
# ProductName  Zucchini - Yellow
# CustomerID
# 33                         0.0
# 200                        0.0
# 264                        0.0
# 356                        0.0
# 412                        0.0
#
# [5 rows x 452 columns]

# %% [markdown]
# ## User Similarity Based Recommendations

# %% [markdown]
# The next step in creating recommendations is calculating similarities. For our user similarity based recommender, we calculated them between customers.

# %%
#create similarity matrix between users, where 1 means completely equal (same user) 
#and 0 means completely different users

sim = pd.DataFrame(1/(1 + squareform(pdist(prods_matrix, 'euclidean'))), 
                   index=prods_matrix.index, 
                   columns=prods_matrix.index)
sim.head()
# Out:
# CustomerID     33        200       264       356       412       464    \
# CustomerID
# 33          1.000000  0.798542  0.817512  0.809747  0.800155  0.808664
# 200         0.798542  1.000000  0.800144  0.796683  0.786241  0.794846
# 264         0.817512  0.800144  1.000000  0.803584  0.804055  0.804834
# 356         0.809747  0.796683  0.803584  1.000000  0.790832  0.798179
# 412         0.800155  0.786241  0.804055  0.790832  1.000000  0.797474
#
# CustomerID     477       639       649       669    ...     97697     97753  \
# CustomerID                                          ...
# 33          0.793170  0.806254  0.804796  0.797597  ...  0.181697  0.183665
# 200         0.799691  0.798179  0.798062  0.795569  ...  0.182266  0.184066
# 264         0.796736  0.802505  0.804374  0.793040  ...  0.182081  0.183862
# 356         0.791346  0.807941  0.793640  0.787507  ...  0.182118  0.183724
# 412         0.787420  0.806112  0.797314  0.795598  ...  0.181754  0.184946
#
# CustomerID     97769     97793     97900     97928     98069     98159  \
# CustomerID
# 33          0.174513  0.197927  0.175583  0.176942  0.181587  0.174803
# 200         0.175210  0.198869  0.175400  0.177303  0.182534  0.175174
# 264         0.174614  0.198530  0.175779  0.177864  0.181978  0.175091
# 356         0.174828  0.198540  0.175586  0.177268  0.181416  0.175185
# 412         0.174538  0.198340  0.175662  0.177428  0.181378  0.175494
#
# CustomerID     98185     98200
# CustomerID
# 33          0.162506  0.170941
# 200         0.162300  0.170876
# 264         0.163000  0.170932
# 356         0.162719  0.171232
# 412         0.162794  0.171587
#
# [5 rows x 1000 columns]

# %% [markdown]
# Once we had our similarity matrix, then we could produce recommendations for each user and package all the recommendations into a data frame.

# %%
#generate a dataframe with a rate of recommendation of each product to each customer
#by taking the dot product of the prods_matrix (products purchased per customer) and 
#the similarity matrix

recommendations = pd.DataFrame(np.dot(sim, prods_matrix), index=sim.index, columns=prods_matrix.columns)

recommendations.head()
# Out:
# ProductName  Anchovy Paste - 56 G Tube  Appetizer - Mini Egg Roll, Shrimp  \
# CustomerID
# 33                            7.156970                           8.237705
# 200                           7.160409                           8.240769
# 264                           7.155057                           8.238747
# 356                           7.160281                           8.244531
# 412                           7.160329                           8.243751
#
# ProductName  Appetizer - Mushroom Tart  Appetizer - Sausage Rolls  \
# CustomerID
# 33                           14.762070                  11.325395
# 200                          14.766760                  11.327441
# 264                          14.772586                  11.330671
# 356                          14.771980                  11.325763
# 412                          14.779857                  11.333033
#
# ProductName  Apricots - Dried  Apricots - Halves  Apricots Fresh  \
# CustomerID
# 33                  11.807736          11.014104       11.700721
# 200                 11.797650          11.012361       11.706214
# 264                 11.798704          11.024883       11.715522
# 356                 11.798644          11.012254       11.702543
# 412                 11.816913          11.017261       11.706033
#
# ProductName  Arizona - Green Tea  Artichokes - Jerusalem  Assorted Desserts  \
# CustomerID
# 33                     14.848343               12.358594          11.129450
# 200                    14.849981               12.369824          11.120381
# 264                    14.856158               12.367901          11.119244
# 356                    14.855287               12.365124          11.123679
# 412                    14.854692               12.378761          11.129693
#
# ProductName  ...  Wine - White, Colubia Cresh  Wine - White, Mosel Gold  \
# CustomerID   ...
# 33           ...                     8.256610                 11.741427
# 200          ...                     8.262630                 11.745717
# 264          ...                     8.255665                 11.746553
# 356          ...                     8.257497                 11.746521
# 412          ...                     8.259207                 11.767682
#
# ProductName  Wine - White, Schroder And Schyl  Wine - Wyndham Estate Bin 777  \
# CustomerID
# 33                                  11.071251                      17.997743
# 200                                 11.072532                      17.988154
# 264                                 11.073045                      18.050192
# 356                                 11.073925                      17.998070
# 412                                 11.090487                      18.056455
#
# ProductName  Wonton Wrappers  Yeast Dry - Fermipan  Yoghurt Tubes  \
# CustomerID
# 33                  9.965741              5.306327      13.735412
# 200                 9.972215              5.308200      13.746228
# 264                 9.970929              5.308565      13.740987
# 356                 9.971839              5.307680      13.737535
# 412                 9.976669              5.308806      13.745529
#
# ProductName  Yogurt - Blueberry, 175 Gr  Yogurt - French Vanilla  \
# CustomerID
# 33                            11.656557                12.490119
# 200                           11.677312                12.481196
# 264                           11.659776                12.480342
# 356                           11.667468                12.498600
# 412                           11.669455                12.485833
#
# ProductName  Zucchini - Yellow
# CustomerID
# 33                   10.611047
# 200                  10.617266
# 264                  10.613088
# 356                  10.618381
# 412                  10.611118
#
# [5 rows x 452 columns]

# %% [markdown]
# ## Deeper Dive Into Our User Similarity Recommendations
#
# Let's deconstruct what we've done and take a deeper dive into how we put this together. Doing this will equip us with the knowledge to be able to put together an item-based similarity recommender in the next section.
#
# After creating an empty dictionary to store our recommendations and getting a unique list of customer IDs to iterate through, we are first identifying the top 5 similar customers to the customer we are trying to generate recommendations for. Let's plug in customer ID 33 and see what results we get.

# %%
#Get a Dataframe of the most similar customers to customer 33
top_5_33 = pd.DataFrame(sim[33].sort_values(ascending=False).head(6)).reset_index()
top_5_33.columns = ['CustomerID', 'Similarity_33']
top_5_33
# Out:
#    CustomerID  Similarity_33
# 0          33       1.000000
# 1         264       0.817512
# 2        3535       0.816412
# 3        1577       0.815517
# 4        2503       0.815050
# 5        3305       0.814926

# %% [markdown]
# What we get is a list containing the 5 customer IDs of the customers whose purchase behavior is most similar to customer 33. We then go back to our customer_products data frame and select just the purchases where the customer ID is in our list of similar customers. We aggregate on product name, summing up the total quantity purchased of each product by all 5 similar customers, and then we rank them by sorting in descending order by the total quantity.

# %%
#Create a dataframe with the sum of the products purchased by the top5 similar customers to ID 33 in descending order
prods_sim_33 = pd.DataFrame(prods_per_consumer[prods_per_consumer['CustomerID'].isin(top_5_33['CustomerID'])]
                            .groupby('ProductName')['Quantity']
                            .count()).sort_values(by='Quantity', ascending=False)
prods_sim_33.head()
# Out:
#                             Quantity
# ProductName
# Towels - Paper / Kraft             4
# Wine - Crozes Hermitage E.         4
# Lamb - Pieces, Diced               4
# Bandage - Flexible Neon            3
# Potatoes - Idaho 100 Count         3

# %% [markdown]
# We now have a ranked list of products that similar customers have purchased, but we haven't taken into consideration yet whether our target customer already purchases any of those items. We want to recommend them items that they might like but haven't purchased before. So we will merge the list of ranked products with our target customer's purchase list and keep only the records for items that the customer has not purchased. These will be the items that we recommend to the customer.

# %%
#right merge of products purchased by customer 33 vs those purchased by similar customers
not_purchased = pd.merge(prods_per_consumer[prods_per_consumer['CustomerID'] == 33], 
                         prods_sim_33, 
                         how='right', 
                         on='ProductName').fillna(0)

#rename columns for clarity
not_purchased.columns = ['CustomerID', 'ProductName', 'Quantity_33', 'Quantity_similar']


#keep only records that were not purchased by customer 33 and order by most purchased
not_purchased = not_purchased[not_purchased['Quantity_33'] == 0].sort_values(by='Quantity_similar', ascending=False)
not_purchased = not_purchased.drop('CustomerID', axis=1)                                                                                        

not_purchased.head()
# Out:
#                       ProductName  Quantity_33  Quantity_similar
# 59  Wine - Blue Nun Qualitatswein          0.0                 3
# 61            Cheese Cloth No 100          0.0                 3
# 62                Beef Wellington          0.0                 3
# 63                   Juice - Lime          0.0                 3
# 64                  Yoghurt Tubes          0.0                 3

# %% [markdown]
# ## Item Similarity Based Recommendations
#
# In this section, you will create an item similarity based recommender system in a step-by-step fashion. Whereas our user similarity based recommender leveraged similarities between customers, this recommender will utilize similarities between products. You already have all the tools in your toolbox, so follow each of the steps below to complete this lab.

# %% [markdown]
# ### Step 1: Create a product distance matrix.

# %%
#Created a product distance matrix but I am not sure this is the matrix asked,
#nor if the distance measure is adequate
sim2 = pd.DataFrame(1/(1 + squareform(pdist(prods_matrix.T, 'euclidean'))), 
                   index=prods_matrix.columns, 
                   columns=prods_matrix.columns)
sim2.head()
# Out:
# ProductName                        Anchovy Paste - 56 G Tube  \
# ProductName
# Anchovy Paste - 56 G Tube                           1.000000
# Appetizer - Mini Egg Roll, Shrimp                   0.204548
# Appetizer - Mushroom Tart                           0.147628
# Appetizer - Sausage Rolls                           0.172469
# Apricots - Dried                                    0.176986
#
# ProductName                        Appetizer - Mini Egg Roll, Shrimp  \
# ProductName
# Anchovy Paste - 56 G Tube                                   0.204548
# Appetizer - Mini Egg Roll, Shrimp                           1.000000
# Appetizer - Mushroom Tart                                   0.144811
# Appetizer - Sausage Rolls                                   0.161784
# Apricots - Dried                                            0.167518
#
# ProductName                        Appetizer - Mushroom Tart  \
# ProductName
# Anchovy Paste - 56 G Tube                           0.147628
# Appetizer - Mini Egg Roll, Shrimp                   0.144811
# Appetizer - Mushroom Tart                           1.000000
# Appetizer - Sausage Rolls                           0.134533
# Apricots - Dried                                    0.129070
#
# ProductName                        Appetizer - Sausage Rolls  \
# ProductName
# Anchovy Paste - 56 G Tube                           0.172469
# Appetizer - Mini Egg Roll, Shrimp                   0.161784
# Appetizer - Mushroom Tart                           0.134533
# Appetizer - Sausage Rolls                           1.000000
# Apricots - Dried                                    0.146787
#
# ProductName                        Apricots - Dried  Apricots - Halves  \
# ProductName
# Anchovy Paste - 56 G Tube                  0.176986           0.171802
# Appetizer - Mini Egg Roll, Shrimp          0.167518           0.166853
# Appetizer - Mushroom Tart                  0.129070           0.134202
# Appetizer - Sausage Rolls                  0.146787           0.151991
# Apricots - Dried                           1.000000           0.150272
#
# ProductName                        Apricots Fresh  Arizona - Green Tea  \
# ProductName
# Anchovy Paste - 56 G Tube                0.177537             0.146791
# Appetizer - Mini Egg Roll, Shrimp        0.169750             0.151919
# Appetizer - Mushroom Tart                0.134829             0.123312
# Appetizer - Sausage Rolls                0.146343             0.132872
# Apricots - Dried                         0.149056             0.135642
#
# ProductName                        Artichokes - Jerusalem  Assorted Desserts  \
# ProductName
# Anchovy Paste - 56 G Tube                        0.170806           0.185490
# Appetizer - Mini Egg Roll, Shrimp                0.167490           0.169360
# Appetizer - Mushroom Tart                        0.133959           0.131307
# Appetizer - Sausage Rolls                        0.141366           0.147651
# Apricots - Dried                                 0.143909           0.151160
#
# ProductName                        ...  Wine - White, Colubia Cresh  \
# ProductName                        ...
# Anchovy Paste - 56 G Tube          ...                     0.207128
# Appetizer - Mini Egg Roll, Shrimp  ...                     0.201349
# Appetizer - Mushroom Tart          ...                     0.147013
# Appetizer - Sausage Rolls          ...                     0.163345
# Apricots - Dried                   ...                     0.164177
#
# ProductName                        Wine - White, Mosel Gold  \
# ProductName
# Anchovy Paste - 56 G Tube                          0.174772
# Appetizer - Mini Egg Roll, Shrimp                  0.167963
# Appetizer - Mushroom Tart                          0.132060
# Appetizer - Sausage Rolls                          0.148847
# Apricots - Dried                                   0.147783
#
# ProductName                        Wine - White, Schroder And Schyl  \
# ProductName
# Anchovy Paste - 56 G Tube                                  0.179959
# Appetizer - Mini Egg Roll, Shrimp                          0.174971
# Appetizer - Mushroom Tart                                  0.134859
# Appetizer - Sausage Rolls                                  0.151577
# Apricots - Dried                                           0.154139
#
# ProductName                        Wine - Wyndham Estate Bin 777  \
# ProductName
# Anchovy Paste - 56 G Tube                               0.123265
# Appetizer - Mini Egg Roll, Shrimp                       0.121653
# Appetizer - Mushroom Tart                               0.112904
# Appetizer - Sausage Rolls                               0.120694
# Apricots - Dried                                        0.118330
#
# ProductName                        Wonton Wrappers  Yeast Dry - Fermipan  \
# ProductName
# Anchovy Paste - 56 G Tube                 0.175729              0.237627
# Appetizer - Mini Egg Roll, Shrimp         0.172053              0.212067
# Appetizer - Mushroom Tart                 0.138671              0.154310
# Appetizer - Sausage Rolls                 0.149241              0.167488
# Apricots - Dried                          0.147415              0.169317
#
# ProductName                        Yoghurt Tubes  Yogurt - Blueberry, 175 Gr  \
# ProductName
# Anchovy Paste - 56 G Tube               0.167350                    0.180573
# Appetizer - Mini Egg Roll, Shrimp       0.164238                    0.178819
# Appetizer - Mushroom Tart               0.133518                    0.138508
# Appetizer - Sausage Rolls               0.143900                    0.149854
# Apricots - Dried                        0.147825                    0.153907
#
# ProductName                        Yogurt - French Vanilla  Zucchini - Yellow
# ProductName
# Anchovy Paste - 56 G Tube                         0.172157           0.169273
# Appetizer - Mini Egg Roll, Shrimp                 0.165428           0.168096
# Appetizer - Mushroom Tart                         0.134408           0.132237
# Appetizer - Sausage Rolls                         0.143585           0.144066
# Apricots - Dried                                  0.146914           0.151037
#
# [5 rows x 452 columns]

# %% [markdown]
# ### Step 2: Get the products purchased for a specific customer of your choice.

# %%
#products purchased by customer 200
prods_200 = prods_per_consumer[prods_per_consumer['CustomerID']==200].reset_index().drop('index', axis=1)
prods_200.head()
# Out:
#    CustomerID                        ProductName  Quantity
# 0         200         Bacardi Breezer - Tropical         1
# 1         200                      Bagel - Plain         1
# 2         200  Bar - Granola Trail Mix Fruit Nut         1
# 3         200               Beef - Ground Medium         1
# 4         200     Beef - Montreal Smoked Brisket         1

# %% [markdown]
# ### Step 3: For each product the customer purchased, get a list of the top 5 similar products. Package the lists into a nested list, flatten the list, and then filter out any products the customer has already purchased.

# %%
#2 lists comprehensions
#The first one a nested one for the top 5 similar products, ordering the product column in the similar matrix
#Getting the first 6 results but discarding the 1st one (index 0), since it is the same product
sim_lst = [list(sim2[x].sort_values(ascending=False).head(6).index)[1:] for x in prods_200['ProductName']]

#The second one is a flattened list based on the first with the condition that the product is not in the 
#dataframe of products purchased by customer 200
sim_lst = [it for item in sim_lst for it in item if it not in prods_200['ProductName']]

# %% [markdown]
# ### Step 4: Count the number of times each similar product occurs in your filtered list. Sort and return a list containing the top 5 items.

# %%
#created a dictionary with keys = product names and values = counts in the list
sim_dict = {}
for a in sim_lst:
    if a not in sim_dict.keys():
        sim_dict[a] = 1
    else:
        sim_dict[a] += 1

#passed the dictionary to a dataframe, sorted_values and got the top 5 products        
top_5_sim = pd.DataFrame.from_dict(sim_dict, 
                                   orient='index').sort_values(0, 
                                                               ascending=False).head(5).reset_index()
top_5_sim.columns = ['ProductName', 'SimilarCount']
top_5_sim
# Out:
#                         ProductName  SimilarCount
# 0              Yeast Dry - Fermipan            61
# 1  Longos - Grilled Salmon With Bbq            52
# 2        Spice - Peppercorn Melange            44
# 3                       Blueberries            25
# 4                       Scampi Tail            24

# %% [markdown]
# ### Step 5: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 2 through 4 for each and appending the results of each iteration to the dictionary you created.

# %%
#Got a list of all Customer IDs
customers = list(recommendations.index)

#defined function that will do the job
def rec_products(lst, prods, matrix):
    #creating temporary variables
    sim_dict = {}
    total_dict = {}
    tmp = pd.DataFrame()
    #will iterate over the customers list
    for client in lst:
        #getting the products DF for a specified client
        tmp = prods[prods['CustomerID']==client].reset_index().drop('index', axis=1)
        #list comprehension to get nested list of similar products
        tmp_lst = [list(matrix[x].sort_values(ascending=False).head(6).index)[1:] for x in tmp['ProductName']]
        #flattening the list and removing purchased products
        tmp_lst = [it for item in tmp_lst for it in item if it not in tmp['ProductName']]
        #counting values in a dictionary
        for a in tmp_lst:
            if a not in sim_dict.keys():
                sim_dict[a] = 1
            else:
                sim_dict[a] += 1
        #getting list of keys for the 5 largest values, adding to bigger dictionary, in which each client is a key
        total_dict[client] = nlargest(5, sim_dict, key=sim_dict.get)
    #return bigger dictionary
    return total_dict

#This code is terrible! In the previous exercise we had done it completely with pandas, why lists and loops??

# %% [markdown]
# ### Step 6: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
#Something is not right... The code works but this df is just... wrong... 
#Why would we recommend almost the same products to everyone?
#Where did I get it wrong?

top_5_products = pd.DataFrame.from_dict(rec_products(customers, prods_per_consumer, sim2), orient='index')
top_5_products.head()
# Out:
#                           0                                 1  \
# 33     Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 200    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 264    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 356    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 412    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 464    Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 477    Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 639    Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 649    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 669    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 694    Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 756    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 883    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 891    Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1008   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1034   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1066   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1072   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1336   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1428   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1435   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1534   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1577   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1594   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1754   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1839   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 1920   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 2187   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 2329   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# 2503   Yeast Dry - Fermipan  Longos - Grilled Salmon With Bbq
# ...                     ...                               ...
# 95314  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 95372  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 95819  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96024  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96088  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96272  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96522  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96524  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96560  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96615  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96666  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 96684  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97029  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97052  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97063  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97093  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97201  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97282  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97324  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97495  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97697  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97753  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97769  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97793  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97900  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 97928  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 98069  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 98159  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 98185  Yeast Dry - Fermipan        Spice - Peppercorn Melange
# 98200  Yeast Dry - Fermipan        Spice - Peppercorn Melange
#
#                                       2                          3  \
# 33           Spice - Peppercorn Melange  Anchovy Paste - 56 G Tube
# 200          Spice - Peppercorn Melange  Anchovy Paste - 56 G Tube
# 264          Spice - Peppercorn Melange                Blueberries
# 356          Spice - Peppercorn Melange  Anchovy Paste - 56 G Tube
# 412          Spice - Peppercorn Melange  Anchovy Paste - 56 G Tube
# 464    Longos - Grilled Salmon With Bbq  Anchovy Paste - 56 G Tube
# 477    Longos - Grilled Salmon With Bbq  Anchovy Paste - 56 G Tube
# 639    Longos - Grilled Salmon With Bbq  Anchovy Paste - 56 G Tube
# 649          Spice - Peppercorn Melange                Blueberries
# 669          Spice - Peppercorn Melange                Blueberries
# 694    Longos - Grilled Salmon With Bbq                Blueberries
# 756          Spice - Peppercorn Melange                Blueberries
# 883          Spice - Peppercorn Melange                Blueberries
# 891          Spice - Peppercorn Melange                Scampi Tail
# 1008         Spice - Peppercorn Melange                Scampi Tail
# 1034         Spice - Peppercorn Melange                Scampi Tail
# 1066         Spice - Peppercorn Melange                Scampi Tail
# 1072         Spice - Peppercorn Melange                Scampi Tail
# 1336         Spice - Peppercorn Melange                Scampi Tail
# 1428         Spice - Peppercorn Melange                Blueberries
# 1435         Spice - Peppercorn Melange                Blueberries
# 1534         Spice - Peppercorn Melange                Blueberries
# 1577         Spice - Peppercorn Melange                Blueberries
# 1594         Spice - Peppercorn Melange                Blueberries
# 1754         Spice - Peppercorn Melange                Blueberries
# 1839         Spice - Peppercorn Melange                Blueberries
# 1920         Spice - Peppercorn Melange                Blueberries
# 2187         Spice - Peppercorn Melange                Blueberries
# 2329         Spice - Peppercorn Melange                Blueberries
# 2503         Spice - Peppercorn Melange                Blueberries
# ...                                 ...                        ...
# 95314  Longos - Grilled Salmon With Bbq                Scampi Tail
# 95372  Longos - Grilled Salmon With Bbq                Scampi Tail
# 95819  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96024  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96088  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96272  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96522  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96524  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96560  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96615  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96666  Longos - Grilled Salmon With Bbq                Scampi Tail
# 96684  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97029  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97052  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97063  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97093  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97201  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97282  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97324  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97495  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97697  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97753  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97769  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97793  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97900  Longos - Grilled Salmon With Bbq                Scampi Tail
# 97928  Longos - Grilled Salmon With Bbq                Scampi Tail
# 98069  Longos - Grilled Salmon With Bbq                Scampi Tail
# 98159  Longos - Grilled Salmon With Bbq                Scampi Tail
# 98185  Longos - Grilled Salmon With Bbq                Scampi Tail
# 98200  Longos - Grilled Salmon With Bbq                Scampi Tail
#
#                                4
# 33                   Blueberries
# 200                  Blueberries
# 264    Anchovy Paste - 56 G Tube
# 356                  Blueberries
# 412                  Blueberries
# 464                  Blueberries
# 477                  Blueberries
# 639                  Blueberries
# 649    Anchovy Paste - 56 G Tube
# 669    Anchovy Paste - 56 G Tube
# 694    Anchovy Paste - 56 G Tube
# 756                  Scampi Tail
# 883                  Scampi Tail
# 891                  Blueberries
# 1008                 Blueberries
# 1034                 Blueberries
# 1066                 Blueberries
# 1072                 Blueberries
# 1336                 Blueberries
# 1428                 Scampi Tail
# 1435                 Scampi Tail
# 1534                 Scampi Tail
# 1577   Anchovy Paste - 56 G Tube
# 1594   Anchovy Paste - 56 G Tube
# 1754   Anchovy Paste - 56 G Tube
# 1839                 Scampi Tail
# 1920   Anchovy Paste - 56 G Tube
# 2187   Anchovy Paste - 56 G Tube
# 2329   Anchovy Paste - 56 G Tube
# 2503   Anchovy Paste - 56 G Tube
# ...                          ...
# 95314  Anchovy Paste - 56 G Tube
# 95372  Anchovy Paste - 56 G Tube
# 95819  Anchovy Paste - 56 G Tube
# 96024  Anchovy Paste - 56 G Tube
# 96088  Anchovy Paste - 56 G Tube
# 96272  Anchovy Paste - 56 G Tube
# 96522  Anchovy Paste - 56 G Tube
# 96524  Anchovy Paste - 56 G Tube
# 96560  Anchovy Paste - 56 G Tube
# 96615  Anchovy Paste - 56 G Tube
# 96666  Anchovy Paste - 56 G Tube
# 96684  Anchovy Paste - 56 G Tube
# 97029  Anchovy Paste - 56 G Tube
# 97052  Anchovy Paste - 56 G Tube
# 97063  Anchovy Paste - 56 G Tube
# 97093  Anchovy Paste - 56 G Tube
# 97201  Anchovy Paste - 56 G Tube
# 97282  Anchovy Paste - 56 G Tube
# 97324  Anchovy Paste - 56 G Tube
# 97495  Anchovy Paste - 56 G Tube
# 97697  Anchovy Paste - 56 G Tube
# 97753  Anchovy Paste - 56 G Tube
# 97769  Anchovy Paste - 56 G Tube
# 97793  Anchovy Paste - 56 G Tube
# 97900  Anchovy Paste - 56 G Tube
# 97928  Anchovy Paste - 56 G Tube
# 98069  Anchovy Paste - 56 G Tube
# 98159  Anchovy Paste - 56 G Tube
# 98185  Anchovy Paste - 56 G Tube
# 98200  Anchovy Paste - 56 G Tube
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Recommending Items to a New Customer
#
# Suppose we get a new customer and on their first visit, they purchase the following items and quantities.

# %%
#? which ones?

# %% [markdown]
# ### Step 7: Recommend 5 products to this new customer using a user similarity approach.

# %%
#unable to solve, need more information

# %% [markdown]
# ### Step 8: Recommend 5 products to this new customer using a item similarity approach.

# %%
#unable to solve, need more information
